# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
yaslistesi = [10,20,30,40,40,40,50,50,60,60,70,80]

# %%
kilolistesi = [20,76,84,65,63,82,43,75,67,123,77,70]

# %%
np_yas = np.array(yaslistesi)

# %%
np_kilo = np.array(kilolistesi)

# %%
plt.plot(np_yas,np_kilo,"g")
plt.xlabel("Yaş")
plt.ylabel("kilo")
plt.title("Yaş - Kilo Grafiği")
# Out:
# Text(0.5, 1.0, 'Yaş - Kilo Grafiği')

# %%
np_dizisi = np.linspace(0,10,20)

# %%
np_dizisi
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
np_dizisi2 = np_dizisi ** 3

# %%
np_dizisi2
# Out:
# array([0.00000000e+00, 1.45793847e-01, 1.16635078e+00, 3.93643388e+00,
#        9.33080624e+00, 1.82242309e+01, 3.14914711e+01, 5.00072897e+01,
#        7.46464499e+01, 1.06283715e+02, 1.45793847e+02, 1.94051611e+02,
#        2.51931768e+02, 3.20309083e+02, 4.00058318e+02, 4.92054235e+02,
#        5.97171599e+02, 7.16285173e+02, 8.50269719e+02, 1.00000000e+03])

# %%
plt.plot(np_dizisi,np_dizisi2,"g")
plt.xlabel("Dizi")
plt.ylabel("Dizib")
# Out:
# Text(0, 0.5, 'Dizib')

# %%
plt.plot(np_dizisi2,np_dizisi,"g--")

# %%
plt.subplot(1,2,1)
plt.plot(np_dizisi,np_dizisi2,"r*-")
plt.subplot(1,2,2) #1 sıra 2 kolon olacak ve 2. grafik çizdirilecek
plt.plot(np_dizisi2,np_dizisi,"b--")

# %%
figureAxes = benimfigure.add_axes([0.2,0.2,0.9,0.9])

# %%
benimfigure = plt.figure()
figureAxes.plot(np_dizisi,np_dizisi2,"g")
figureAxes.set_xlabel("X ekseni")
figureAxes.set_ylabel("Y ekseni")
figureAxes.set_title("Grafik")
# Out:
# Text(0.5, 1.0, 'Grafik')

# %%
figure2 = plt.figure()
eksen1 = figure2.add_axes([0.1,0.1,0.9,0.9])
eksen2 = figure2.add_axes([0.2,0.4,0.3,0.3])

eksen1.plot(np_dizisi,np_dizisi2,"g")
eksen1.set_xlabel("X ekseni")
eksen1.set_ylabel("Y ekseni")
eksen1.set_title("Eksen 1")

eksen2.plot(np_dizisi2,np_dizisi,"b")
eksen2.set_xlabel("X ekseni küçük")
eksen2.set_ylabel("Y ekseni küçük")
eksen2.set_title("Eksen 2")
# Out:
# Text(0.5, 1.0, 'Eksen 2')

# %%
(benimfigure,benimEksenler) = plt.subplots(nrows= 1,ncols=2)
type(benimEksenler)
for eksen in benimEksenler:
    eksen.plot(np_dizisi,np_dizisi2,"g")
    eksen.set_xlabel("X")
plt.tight_layout()

# %%
yenifigur = plt.figure()

yenieksen = yenifigur.add_axes([0.1,0.1,0.9,0.9])

yenieksen.plot(np_dizisi,np_dizisi2,label = "nump dizisi ** 2")
yenieksen.legend()
